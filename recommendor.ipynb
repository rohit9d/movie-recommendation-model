# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.metrics.pairwise import linear_kernel, cosine_similarity
from surprise.model_selection import cross_validate
from surprise import Reader, Dataset, SVD, SVDpp,SlopeOne,NMF,NormalPredictor,KNNBaseline,KNNBasic,KNNWithMeans, KNNWithZScore, BaselineOnly, CoClustering

# %%
#movie recommendation using top movies in the genre
md=pd.read_csv('data/dataset/movies_metadata.csv')

# %%
#creating top movies chart in each genre

md['id']=md['id'].astype('int')
md['id']
# Out:
# 0           862
# 1          8844
# 2         15602
# 3         31357
# 4         11862
#           ...
# 45458    439050
# 45459    111109
# 45460     67758
# 45461    227506
# 45462    461257
# Name: id, Length: 45463, dtype: int32

# %%
#to check top charts using IMDB formula----weighted rating = ((v/v+m).R) + ((v/v+m).C)
#v is the number of votes for the movie
#m is the minimum votes required to be listed in the chart
#R is the average rating of the movie
#C is the mean vote across the whole report

# %%
from ast import literal_eval
md['genres']=md['genres'].fillna('[]').apply(literal_eval)
md['genres']=md['genres'].map(lambda x:[i['name'] for i in x] if isinstance(x,list) else [])

# %%
md['vote_count']=md['vote_count'].fillna(0)
#total vote counts
#total_votes=md['vote_count'].sum()
#print(total_votes)
#minimum votes require-->95%
vote_min=md['vote_count'].astype('int').quantile(0.95).astype(int)
#mean value for vote
C=md[md['vote_average'].notnull()]['vote_average'].mean()

# %%
#creating a column for year
md['year']=pd.to_datetime(md['release_date'],errors='coerce').map(lambda x: str(x).split('-')[0] if x!=np.nan else np.nan)

# %%
#modifying spoken_lagnuages column to consist an array
md['languages']=md['spoken_languages'].fillna('[]').apply(literal_eval).map(lambda x:[i['name'] for i in x] if isinstance(x,list) else [])

# %%
#creating a small dataset with vote_count > minimum value ,is not null and remove unnecessary columns
qual=md[(md['vote_count'] >=vote_min) & (md['vote_count'].notnull())][['adult','budget','genres','id','imdb_id','original_language','original_title','revenue','languages','vote_average','vote_count','year']]

# %%
qual.info()
#qual['vote_count']
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2282 entries, 0 to 45011
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   adult              2282 non-null   bool
#  1   budget             2282 non-null   int64
#  2   genres             2282 non-null   object
#  3   id                 2282 non-null   int32
#  4   imdb_id            2282 non-null   object
#  5   original_language  2282 non-null   object
#  6   original_title     2282 non-null   object
#  7   revenue            2282 non-null   float64
#  8   languages          2282 non-null   object
#  9   vote_average       2282 non-null   float64
#  10  vote_count         2282 non-null   float64
#  11  year               2282 non-null   object
# dtypes: bool(1), float64(3), int32(1), int64(1), object(6)
# memory usage: 207.3+ KB

# %%
#calculating weighted rating of each movie
#a=qual.apply(lambda x: (x.vote_count/(x.vote_count+vote_min))*C + (x.vote_count/(x.vote_count+vote_min))*x.vote_average)
def rating(row):
    return ((row['vote_count']/(row['vote_count']+vote_min))*row['vote_average']) + (vote_min/(row['vote_count']+vote_min))*C
    #row['vote_count']=row['vote_count']*2
qual['weighted_rating']=qual.apply(rating,axis=1)
#qual['rating']=qual.apply(lambda x: (x.vote_count/(x.vote_count+vote_min))*C + (x.vote_count/(x.vote_count+vote_min))*x.vote_average ,axis=1)

# %%
#top 250 movies are 
qual.sort_values('weighted_rating',ascending=False).head(20)
# Out:
#        adult     budget                                             genres  \
# 314    False   25000000                                     [Drama, Crime]
# 834    False    6000000                                     [Drama, Crime]
# 12481  False  185000000                   [Drama, Action, Crime, Thriller]
# 2843   False   63000000                                            [Drama]
# 292    False    8000000                                  [Thriller, Crime]
# 351    False   55000000                           [Comedy, Drama, Romance]
# 522    False   22000000                              [Drama, History, War]
# 23672  False    3300000                                            [Drama]
# 5481   False   15000000            [Fantasy, Adventure, Animation, Family]
# 1154   False   18000000               [Adventure, Action, Science Fiction]
# 15480  False  160000000  [Action, Thriller, Science Fiction, Mystery, A...
# 2211   False   20000000                                    [Comedy, Drama]
# 18465  False   13000000                                    [Drama, Comedy]
# 22878  False  165000000                [Adventure, Drama, Science Fiction]
# 1178   False   13000000                                     [Drama, Crime]
# 7000   False   94000000                       [Adventure, Fantasy, Action]
# 289    False   16000000                           [Thriller, Crime, Drama]
# 1152   False    3000000                                            [Drama]
# 3030   False   60000000                            [Fantasy, Drama, Crime]
# 256    False   11000000               [Adventure, Action, Science Fiction]
#
#            id    imdb_id original_language  \
# 314       278  tt0111161                en
# 834       238  tt0068646                en
# 12481     155  tt0468569                en
# 2843      550  tt0137523                en
# 292       680  tt0110912                en
# 351        13  tt0109830                en
# 522       424  tt0108052                en
# 23672  244786  tt2582802                en
# 5481      129  tt0245429                ja
# 1154     1891  tt0080684                en
# 15480   27205  tt1375666                en
# 2211      637  tt0118799                it
# 18465   77338  tt1675434                fr
# 22878  157336  tt0816692                en
# 1178      240  tt0071562                en
# 7000      122  tt0167260                en
# 289       101  tt0110413                fr
# 1152      510  tt0073486                en
# 3030      497  tt0120689                en
# 256        11  tt0076759                en
#
#                                       original_title       revenue  \
# 314                         The Shawshank Redemption  2.834147e+07
# 834                                    The Godfather  2.450664e+08
# 12481                                The Dark Knight  1.004558e+09
# 2843                                      Fight Club  1.008538e+08
# 292                                     Pulp Fiction  2.139288e+08
# 351                                     Forrest Gump  6.779454e+08
# 522                                 Schindler's List  3.213656e+08
# 23672                                       Whiplash  1.309200e+07
# 5481                                        千と千尋の神隠し  2.749251e+08
# 1154                         The Empire Strikes Back  5.384000e+08
# 15480                                      Inception  8.255328e+08
# 2211                                 La vita è bella  2.294000e+08
# 18465                                   Intouchables  4.264809e+08
# 22878                                   Interstellar  6.751200e+08
# 1178                          The Godfather: Part II  4.754284e+07
# 7000   The Lord of the Rings: The Return of the King  1.118889e+09
# 289                                             Léon  4.528497e+07
# 1152                 One Flew Over the Cuckoo's Nest  1.089813e+08
# 3030                                  The Green Mile  2.846000e+08
# 256                                        Star Wars  7.753980e+08
#
#                                   languages  vote_average  vote_count  year  \
# 314                               [English]           8.5      8358.0  1994
# 834              [English, Italiano, Latin]           8.5      6024.0  1972
# 12481                        [English, 普通话]           8.3     12269.0  2008
# 2843                              [English]           8.3      9678.0  1999
# 292            [English, Español, Français]           8.3      8670.0  1994
# 351                               [English]           8.2      8147.0  1994
# 522    [Deutsch, Polski, עִבְרִית, English]           8.3      4436.0  1993
# 23672                             [English]           8.3      4376.0  2014
# 5481                                  [日本語]           8.3      3968.0  2001
# 1154                              [English]           8.2      5998.0  1980
# 15480                             [English]           8.1     14075.0  2010
# 2211           [English, Deutsch, Italiano]           8.3      3643.0  1997
# 18465                   [English, Français]           8.2      5410.0  2011
# 22878                             [English]           8.1     11187.0  2014
# 1178    [English, Italiano, Latin, Español]           8.3      3418.0  1974
# 7000                              [English]           8.1      8226.0  2003
# 289                               [English]           8.2      4293.0  1994
# 1152                              [English]           8.3      3001.0  1975
# 3030                    [Français, English]           8.2      4166.0  1999
# 256                               [English]           8.1      6778.0  1977
#
#        weighted_rating
# 314           8.358058
# 834           8.306750
# 12481         8.208580
# 2843          8.185153
# 292           8.172436
# 351           8.069707
# 522           8.061508
# 23672         8.058533
# 5481          8.036147
# 1154          8.026168
# 15480         8.025929
# 2211          8.015109
# 18465         8.008674
# 22878         8.007520
# 1178          7.998464
# 7000          7.975896
# 289           7.963454
# 1152          7.961847
# 3030          7.956922
# 256           7.950975

# %%
#movie should have votes more than vot_min to be considered

# %%
#get all unique values for genres
genres=[]
for x in md['genres']:
    [genres.append(i) for i in x]

genres=set(genres)

# %%
#creating movie recommendation model as per genres (will return top 5 or what ever is paassed)
#creating function that accepts genre
#df=pd.DataFrame()

df=qual
df['gen']=0
def found(a,x,ic):
    if x in a['genres'] and (a.gen==0) :
        return ic
    else:
        return a.gen

def recommender_1(genre,val):
    ind=1
    for gen in genre:
        df['gen']=df.apply(found,args=(gen,ind ),axis='columns')
        ind=ind+1
    v=df[df['gen']!=0].groupby('gen').apply(lambda x:x.sort_values(['weighted_rating'],ascending=False)).reset_index(drop=True)
    return v.groupby('gen').head(val)
f=recommender_1(['Comedy','Animation'],5)
#df
#gen_md.head()

# %%
#printing top 5 movies 0for both genres selected
def get_recommendations_1(name):
    genres_list=qual[qual['original_title']==name].genres
    val=recommender_1(genres_list,3)
    return val
get_recommendations_1('The Godfather')
# Out:
#      adult    budget                                   genres     id  \
# 0    False  55000000                 [Comedy, Drama, Romance]     13
# 1    False  20000000                          [Comedy, Drama]    637
# 2    False  13000000                          [Drama, Comedy]  77338
# 748  False  15000000  [Fantasy, Adventure, Animation, Family]    129
# 749  False  45000000               [Family, Animation, Drama]   8587
# 750  False  24000000          [Fantasy, Animation, Adventure]   4935
#
#        imdb_id original_language   original_title      revenue  \
# 0    tt0109830                en     Forrest Gump  677945399.0
# 1    tt0118799                it  La vita è bella  229400000.0
# 2    tt1675434                fr     Intouchables  426480871.0
# 748  tt0245429                ja         千と千尋の神隠し  274925095.0
# 749  tt0110357                en    The Lion King  788241776.0
# 750  tt0347149                ja          ハウルの動く城  234710455.0
#
#                         languages  vote_average  vote_count  year  \
# 0                       [English]           8.2      8147.0  1994
# 1    [English, Deutsch, Italiano]           8.3      3643.0  1997
# 2             [English, Français]           8.2      5410.0  2011
# 748                         [日本語]           8.3      3968.0  2001
# 749                     [English]           8.0      5520.0  1994
# 750                         [日本語]           8.2      2049.0  2004
#
#      weighted_rating  gen
# 0           8.069707    1
# 1           8.015109    1
# 2           8.008674    1
# 748         8.036147    2
# 749         7.826757    2
# 750         7.749591    2

# %%
#modifying genre based recommendation as comdey,drama cannot be put in similar to crim,drama just because both have genre-drama

# %%
#recommeder as per cast
#import data that has cast
cast_data=pd.read_csv('data/dataset/credits.csv')

md['id']=md['id'].astype('int')
#merge this with main dataset
md=md.merge(cast_data,on='id')

# %%
#md.head(2)
md
# Out:
#        adult                              belongs_to_collection    budget  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      False                                                NaN  65000000
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      False                                                NaN  16000000
# 4      False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 45533  False                                                NaN         0
# 45534  False                                                NaN         0
# 45535  False                                                NaN         0
# 45536  False                                                NaN         0
# 45537  False                                                NaN         0
#
#                              genres                              homepage  \
# 0       [Animation, Comedy, Family]  http://toystory.disney.com/toy-story
# 1      [Adventure, Fantasy, Family]                                   NaN
# 2                 [Romance, Comedy]                                   NaN
# 3          [Comedy, Drama, Romance]                                   NaN
# 4                          [Comedy]                                   NaN
# ...                             ...                                   ...
# 45533               [Drama, Family]  http://www.imdb.com/title/tt6209470/
# 45534                       [Drama]                                   NaN
# 45535     [Action, Drama, Thriller]                                   NaN
# 45536                            []                                   NaN
# 45537                            []                                   NaN
#
#            id    imdb_id original_language               original_title  \
# 0         862  tt0114709                en                    Toy Story
# 1        8844  tt0113497                en                      Jumanji
# 2       15602  tt0113228                en             Grumpier Old Men
# 3       31357  tt0114885                en            Waiting to Exhale
# 4       11862  tt0113041                en  Father of the Bride Part II
# ...       ...        ...               ...                          ...
# 45533  439050  tt6209470                fa                      رگ خواب
# 45534  111109  tt2028550                tl          Siglo ng Pagluluwal
# 45535   67758  tt0303758                en                     Betrayal
# 45536  227506  tt0008536                en          Satana likuyushchiy
# 45537  461257  tt6980792                en                     Queerama
#
#                                                 overview  ...    status  \
# 0      Led by Woody, Andy's toys live happily in his ...  ...  Released
# 1      When siblings Judy and Peter discover an encha...  ...  Released
# 2      A family wedding reignites the ancient feud be...  ...  Released
# 3      Cheated on, mistreated and stepped on, the wom...  ...  Released
# 4      Just when George Banks has recovered from his ...  ...  Released
# ...                                                  ...  ...       ...
# 45533        Rising and falling between a man and woman.  ...  Released
# 45534  An artist struggles to finish his work while a...  ...  Released
# 45535  When one of her hits goes wrong, a professiona...  ...  Released
# 45536  In a small town live two brothers, one a minis...  ...  Released
# 45537  50 years after decriminalisation of homosexual...  ...  Released
#
#                                                  tagline  \
# 0                                                    NaN
# 1              Roll the dice and unleash the excitement!
# 2      Still Yelling. Still Fighting. Still Ready for...
# 3      Friends are the people who let you be yourself...
# 4      Just When His World Is Back To Normal... He's ...
# ...                                                  ...
# 45533         Rising and falling between a man and woman
# 45534                                                NaN
# 45535                             A deadly game of wits.
# 45536                                                NaN
# 45537                                                NaN
#
#                              title  video vote_average  vote_count  year  \
# 0                        Toy Story  False          7.7      5415.0  1995
# 1                          Jumanji  False          6.9      2413.0  1995
# 2                 Grumpier Old Men  False          6.5        92.0  1995
# 3                Waiting to Exhale  False          6.1        34.0  1995
# 4      Father of the Bride Part II  False          5.7       173.0  1995
# ...                            ...    ...          ...         ...   ...
# 45533                       Subdue  False          4.0         1.0   NaT
# 45534          Century of Birthing  False          9.0         3.0  2011
# 45535                     Betrayal  False          3.8         6.0  2003
# 45536             Satan Triumphant  False          0.0         0.0  1917
# 45537                     Queerama  False          0.0         0.0  2017
#
#                  languages                                               cast  \
# 0                [English]  [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1      [English, Français]  [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2                [English]  [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3                [English]  [{'cast_id': 1, 'character': "Savannah 'Vannah...
# 4                [English]  [{'cast_id': 1, 'character': 'George Banks', '...
# ...                    ...                                                ...
# 45533              [فارسی]  [{'cast_id': 0, 'character': '', 'credit_id': ...
# 45534                   []  [{'cast_id': 1002, 'character': 'Sister Angela...
# 45535            [English]  [{'cast_id': 6, 'character': 'Emily Shaw', 'cr...
# 45536                   []  [{'cast_id': 2, 'character': '', 'credit_id': ...
# 45537            [English]                                                 []
#
#                                                     crew
# 0      [{'credit_id': '52fe4284c3a36847f8024f49', 'de...
# 1      [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...
# 2      [{'credit_id': '52fe466a9251416c75077a89', 'de...
# 3      [{'credit_id': '52fe44779251416c91011acb', 'de...
# 4      [{'credit_id': '52fe44959251416c75039ed7', 'de...
# ...                                                  ...
# 45533  [{'credit_id': '5894a97d925141426c00818c', 'de...
# 45534  [{'credit_id': '52fe4af1c3a36847f81e9b15', 'de...
# 45535  [{'credit_id': '52fe4776c3a368484e0c8387', 'de...
# 45536  [{'credit_id': '533bccebc3a36844cf0011a7', 'de...
# 45537  [{'credit_id': '593e676c92514105b702e68e', 'de...
#
# [45538 rows x 28 columns]

# %%
#checking director
#director=cast_data[['crew','id']]
#director['crew']=director['crew'].apply(literal_eval)
md['crew']=md['crew'].apply(literal_eval)
def get_director(row):
    #print(row)
    #print(1)
    for a in row:
        if a['job']=='Director':
            return a['name']
    return "NA"
md['director']=md['crew'].apply(get_director)
#md['cast']

# %%
#for rest of the crew lets take only the fellow whose count is more than 90%
#top 10 crew
md['cast']=md['cast'].apply(literal_eval)
md['cast']=md['cast'].apply(lambda x:[a['name'] for a in x] if isinstance(x,list) else [])

# %%
cast_list=[]
for x in md['cast']:
    [cast_list.append(i) for i in x]
cast_li=pd.DataFrame()
cast_li['name']=cast_list
cast_li['cn']=1
cast_li=cast_li.groupby('name').cn.agg([sum]).reset_index().sort_values(by='sum',ascending=False)
cast_li.head(200)
#involves a lot of side actors.. Hence take first 4-5 characters for each movie
# Out:
#                       name  sum
# 19954         Bess Flowers  241
# 34454      Christopher Lee  148
# 94329           John Wayne  125
# 169114   Samuel L. Jackson  123
# 132443       Michael Caine  110
# ...                    ...  ...
# 127822    Mary Steenburgen   61
# 114372      Liev Schreiber   61
# 171428        Sean Connery   61
# 31350   Charlotte Rampling   61
# 57797        Ewan McGregor   61
#
# [200 rows x 2 columns]

# %%
#get all unique values for Cast
md['cast']=md['cast'].apply(lambda x: x[:3] if len(x)>=3 else x)
md['cast']
# Out:
# 0                      [Tom Hanks, Tim Allen, Don Rickles]
# 1           [Robin Williams, Jonathan Hyde, Kirsten Dunst]
# 2               [Walter Matthau, Jack Lemmon, Ann-Margret]
# 3        [Whitney Houston, Angela Bassett, Loretta Devine]
# 4               [Steve Martin, Diane Keaton, Martin Short]
#                                ...
# 45533          [Leila Hatami, Kourosh Tahami, Elham Korda]
# 45534           [Angel Aquino, Perry Dizon, Hazel Orencio]
# 45535         [Erika Eleniak, Adam Baldwin, Julie du Page]
# 45536    [Iwan Mosschuchin, Nathalie Lissenko, Pavel Pa...
# 45537                                                   []
# Name: cast, Length: 45538, dtype: object

# %%
#formating and using keywords

keywds=pd.read_csv('data/dataset/keywords.csv')
keywds['keywords']=keywds['keywords'].apply(literal_eval)
keywds['keywords']=keywds['keywords'].apply(lambda x:[i['name'] for i in x] if isinstance(x,list) else [])
md=md.merge(keywds,on='id')

# %%
md=md.drop('crew',axis=1)

# %%
#checking unique keywords
ke=md.apply(lambda x: pd.Series(x['keywords']),axis=1).stack().reset_index(drop=True)
ke.name='keyword'
ke.value_counts()
# Out:
# C:\Users\rohit\anaconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
# woman director             3128
# independent film           1942
# murder                     1314
# based on novel              841
# musical                     734
#                            ...
# seinen                        1
# gus                           1
# investing                     1
# shakespeare's king lear       1
# star wars spoof scene         1
# Name: keyword, Length: 19956, dtype: int64

# %%
a=[]
for x in md['keywords']:
    [a.append(i) for i in x]
a=pd.Series(a,name='keyword')
a=a.value_counts()
#keep key words that occur more than once
a=a[a>1]

# %%
def filter_keywords(x):
    words = []
    for i in x:
        if i in a:
            words.append(i)
    return words

# %%
md['keywords'] = md['keywords'].apply(filter_keywords)
#remove spaces betwwen keywords to take them as one 
md['keywords'] = md['keywords'].apply(lambda x: [str.lower(i.replace(" ","")) for i in x])
#use lemma to avoid getting different count for similar words
md['keywords']=md['keywords'].apply(lambda x:' '.join(x))

md.head(2)
#using smaller dataset for matching for now to check model
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
#
#                          genres                              homepage    id  \
# 0   [Animation, Comedy, Family]  http://toystory.disney.com/toy-story   862
# 1  [Adventure, Fantasy, Family]                                   NaN  8844
#
#      imdb_id original_language original_title  \
# 0  tt0114709                en      Toy Story
# 1  tt0113497                en        Jumanji
#
#                                             overview  ...  \
# 0  Led by Woody, Andy's toys live happily in his ...  ...
# 1  When siblings Judy and Peter discover an encha...  ...
#
#                                      tagline      title  video vote_average  \
# 0                                        NaN  Toy Story  False          7.7
# 1  Roll the dice and unleash the excitement!    Jumanji  False          6.9
#
#   vote_count  year            languages  \
# 0     5415.0  1995            [English]
# 1     2413.0  1995  [English, Français]
#
#                                              cast       director  \
# 0             [Tom Hanks, Tim Allen, Don Rickles]  John Lasseter
# 1  [Robin Williams, Jonathan Hyde, Kirsten Dunst]   Joe Johnston
#
#                                             keywords
# 0  jealousy toy boy friendship friends rivalry bo...
# 1  boardgame disappearance basedonchildren'sbook ...
#
# [2 rows x 29 columns]

# %%
import en_core_web_lg
nlp = en_core_web_lg.load()
z=md['keywords'].apply(lambda x:" ".join([token.lemma_ for token in nlp(x)]))
z
# Out:
# 0        jealousy toy boy friendship friend rivalry boy...
# 1        boardgame disappearance basedonchildren'sbook ...
# 2           fishing bestfriend duringcreditsstinger oldmen
# 3        basedonnovel interracialrelationship singlemot...
# 4        baby midlifecrisis confidence age daughter mot...
#                                ...
# 46623                                           tragiclove
# 46624                                    artist play pinoy
# 46625
# 46626
# 46627
# Name: keywords, Length: 46628, dtype: object

# %%
md['keywords']=z.map(lambda x:[x])
md.head(5)
#md[md['id'].isin(links_small)]
#links_small
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                          genres                              homepage     id  \
# 0   [Animation, Comedy, Family]  http://toystory.disney.com/toy-story    862
# 1  [Adventure, Fantasy, Family]                                   NaN   8844
# 2             [Romance, Comedy]                                   NaN  15602
# 3      [Comedy, Drama, Romance]                                   NaN  31357
# 4                      [Comedy]                                   NaN  11862
#
#      imdb_id original_language               original_title  \
# 0  tt0114709                en                    Toy Story
# 1  tt0113497                en                      Jumanji
# 2  tt0113228                en             Grumpier Old Men
# 3  tt0114885                en            Waiting to Exhale
# 4  tt0113041                en  Father of the Bride Part II
#
#                                             overview  ...  \
# 0  Led by Woody, Andy's toys live happily in his ...  ...
# 1  When siblings Judy and Peter discover an encha...  ...
# 2  A family wedding reignites the ancient feud be...  ...
# 3  Cheated on, mistreated and stepped on, the wom...  ...
# 4  Just when George Banks has recovered from his ...  ...
#
#                                              tagline  \
# 0                                                NaN
# 1          Roll the dice and unleash the excitement!
# 2  Still Yelling. Still Fighting. Still Ready for...
# 3  Friends are the people who let you be yourself...
# 4  Just When His World Is Back To Normal... He's ...
#
#                          title  video vote_average vote_count  year  \
# 0                    Toy Story  False          7.7     5415.0  1995
# 1                      Jumanji  False          6.9     2413.0  1995
# 2             Grumpier Old Men  False          6.5       92.0  1995
# 3            Waiting to Exhale  False          6.1       34.0  1995
# 4  Father of the Bride Part II  False          5.7      173.0  1995
#
#              languages                                               cast  \
# 0            [English]                [Tom Hanks, Tim Allen, Don Rickles]
# 1  [English, Français]     [Robin Williams, Jonathan Hyde, Kirsten Dunst]
# 2            [English]         [Walter Matthau, Jack Lemmon, Ann-Margret]
# 3            [English]  [Whitney Houston, Angela Bassett, Loretta Devine]
# 4            [English]         [Steve Martin, Diane Keaton, Martin Short]
#
#           director                                           keywords
# 0    John Lasseter  [jealousy toy boy friendship friend rivalry bo...
# 1     Joe Johnston  [boardgame disappearance basedonchildren'sbook...
# 2    Howard Deutch   [fishing bestfriend duringcreditsstinger oldmen]
# 3  Forest Whitaker  [basedonnovel interracialrelationship singlemo...
# 4    Charles Shyer  [baby midlifecrisis confidence age daughter mo...
#
# [5 rows x 29 columns]

# %%
links_small=pd.read_csv('data/dataset/links_small.csv')
links_small = links_small[links_small['tmdbId'].notnull()]['tmdbId'].astype('int')
links_small.columns=['movieId','imdbId','id']
sd=md[md['id'].isin(links_small)]
#sd=sd.reset_index()
sd['tagline']=sd['tagline'].fillna('')
sd['description']=sd['overview']+sd['tagline']
sd['description']=sd['description'].fillna('')
sd=sd.reset_index(drop=True)
# Out:
# C:\Users\rohit\anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\rohit\anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# C:\Users\rohit\anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#md[md['id'].isin(links_small)]
#removing spaces between names to avoid similarity between people with same first name or last name
sd['cast']=sd['cast'].apply(lambda x:[str.lower(i.replace(" ","")) for i in x])
sd['director']=sd['director'].apply(lambda x:str.lower(x.replace(" ","")))
#gving more importance to director by

# %%
md[md['id'].isin(links_small)]
#links_small
sd
# Out:
#       adult                              belongs_to_collection    budget  \
# 0     False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1     False                                                NaN  65000000
# 2     False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3     False                                                NaN  16000000
# 4     False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...     ...                                                ...       ...
# 9214  False                                                NaN   8000000
# 9215  False                                                NaN   1000000
# 9216  False                                                NaN  15050000
# 9217  False                                                NaN  15000000
# 9218  False                                                NaN         0
#
#                                                  genres  \
# 0                           [Animation, Comedy, Family]
# 1                          [Adventure, Fantasy, Family]
# 2                                     [Romance, Comedy]
# 3                              [Comedy, Drama, Romance]
# 4                                              [Comedy]
# ...                                                 ...
# 9214                                            [Drama]
# 9215                                [Thriller, Romance]
# 9216               [Adventure, Drama, History, Romance]
# 9217  [Action, Adventure, Drama, Horror, Science Fic...
# 9218                               [Documentary, Music]
#
#                                    homepage      id    imdb_id  \
# 0      http://toystory.disney.com/toy-story     862  tt0114709
# 1                                       NaN    8844  tt0113497
# 2                                       NaN   15602  tt0113228
# 3                                       NaN   31357  tt0114885
# 4                                       NaN   11862  tt0113041
# ...                                     ...     ...        ...
# 9214                                    NaN  159550  tt0255313
# 9215                                    NaN  392572  tt5165344
# 9216                                    NaN  402672  tt3859980
# 9217                                    NaN  315011  tt4262980
# 9218  http://www.thebeatlesliveproject.com/  391698  tt2531318
#
#      original_language                                     original_title  \
# 0                   en                                          Toy Story
# 1                   en                                            Jumanji
# 2                   en                                   Grumpier Old Men
# 3                   en                                  Waiting to Exhale
# 4                   en                        Father of the Bride Part II
# ...                ...                                                ...
# 9214                en                     The Last Brickmaker in America
# 9215                hi                                             रुस्तम
# 9216                hi                                       Mohenjo Daro
# 9217                ja                                             シン・ゴジラ
# 9218                en  The Beatles: Eight Days a Week - The Touring Y...
#
#                                                overview  ...  \
# 0     Led by Woody, Andy's toys live happily in his ...  ...
# 1     When siblings Judy and Peter discover an encha...  ...
# 2     A family wedding reignites the ancient feud be...  ...
# 3     Cheated on, mistreated and stepped on, the wom...  ...
# 4     Just when George Banks has recovered from his ...  ...
# ...                                                 ...  ...
# 9214  A man must cope with the loss of his wife and ...  ...
# 9215  Rustom Pavri, an honourable officer of the Ind...  ...
# 9216  Village lad Sarman is drawn to big, bad Mohenj...  ...
# 9217  From the mind behind Evangelion comes a hit la...  ...
# 9218  The band stormed Europe in 1963, and, in 1964,...  ...
#
#                                                   title  video vote_average  \
# 0                                             Toy Story  False          7.7
# 1                                               Jumanji  False          6.9
# 2                                      Grumpier Old Men  False          6.5
# 3                                     Waiting to Exhale  False          6.1
# 4                           Father of the Bride Part II  False          5.7
# ...                                                 ...    ...          ...
# 9214                     The Last Brickmaker in America  False          7.0
# 9215                                             Rustom  False          7.3
# 9216                                       Mohenjo Daro  False          6.7
# 9217                                      Shin Godzilla  False          6.6
# 9218  The Beatles: Eight Days a Week - The Touring Y...  False          7.6
#
#      vote_count  year                          languages  \
# 0        5415.0  1995                          [English]
# 1        2413.0  1995                [English, Français]
# 2          92.0  1995                          [English]
# 3          34.0  1995                          [English]
# 4         173.0  1995                          [English]
# ...         ...   ...                                ...
# 9214        1.0  2001                                 []
# 9215       25.0  2016                           [हिन्दी]
# 9216       26.0  2016                           [हिन्दी]
# 9217      152.0  2016  [Italiano, Deutsch, English, 日本語]
# 9218       92.0  2016                          [English]
#
#                                                    cast           director  \
# 0                      [tomhanks, timallen, donrickles]       johnlasseter
# 1           [robinwilliams, jonathanhyde, kirstendunst]        joejohnston
# 2              [waltermatthau, jacklemmon, ann-margret]       howarddeutch
# 3        [whitneyhouston, angelabassett, lorettadevine]     forestwhitaker
# 4               [stevemartin, dianekeaton, martinshort]       charlesshyer
# ...                                                 ...                ...
# 9214        [sidneypoitier, wendycrewson, jayo.sanders]      greggchampion
# 9215             [akshaykumar, ileanad'cruz, eshagupta]    tinusureshdesai
# 9216             [hrithikroshan, poojahegde, kabirbedi]  ashutoshgowariker
# 9217  [hirokihasegawa, yutakatakenouchi, satomiishih...        hideakianno
# 9218            [paulmccartney, ringostarr, johnlennon]          ronhoward
#
#                                                keywords  \
# 0     [jealousy toy boy friendship friend rivalry bo...
# 1     [boardgame disappearance basedonchildren'sbook...
# 2      [fishing bestfriend duringcreditsstinger oldmen]
# 3     [basedonnovel interracialrelationship singlemo...
# 4     [baby midlifecrisis confidence age daughter mo...
# ...                                                 ...
# 9214                                       [friendship]
# 9215                                        [bollywood]
# 9216                                        [bollywood]
# 9217  [monster godzilla giantmonster destruction kaiju]
# 9218                                [music documentary]
#
#                                             description
# 0     Led by Woody, Andy's toys live happily in his ...
# 1     When siblings Judy and Peter discover an encha...
# 2     A family wedding reignites the ancient feud be...
# 3     Cheated on, mistreated and stepped on, the wom...
# 4     Just when George Banks has recovered from his ...
# ...                                                 ...
# 9214  A man must cope with the loss of his wife and ...
# 9215  Rustom Pavri, an honourable officer of the Ind...
# 9216  Village lad Sarman is drawn to big, bad Mohenj...
# 9217  From the mind behind Evangelion comes a hit la...
# 9218  The band stormed Europe in 1963, and, in 1964,...
#
# [9219 rows x 30 columns]

# %%
sd['director']=sd['director'].apply(lambda x:[x,x,x,x,x])
#joining all coumns to apply cosine similarity
sd['col']=sd['cast']+ sd['director']+ sd['keywords']
sd['col']=sd['col'].apply(lambda x:' '.join(x))
sd.head(2)
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
#
#                          genres                              homepage    id  \
# 0   [Animation, Comedy, Family]  http://toystory.disney.com/toy-story   862
# 1  [Adventure, Fantasy, Family]                                   NaN  8844
#
#      imdb_id original_language original_title  \
# 0  tt0114709                en      Toy Story
# 1  tt0113497                en        Jumanji
#
#                                             overview  ...  video vote_average  \
# 0  Led by Woody, Andy's toys live happily in his ...  ...  False          7.7
# 1  When siblings Judy and Peter discover an encha...  ...  False          6.9
#
#   vote_count  year            languages  \
# 0     5415.0  1995            [English]
# 1     2413.0  1995  [English, Français]
#
#                                           cast  \
# 0             [tomhanks, timallen, donrickles]
# 1  [robinwilliams, jonathanhyde, kirstendunst]
#
#                                             director  \
# 0  [johnlasseter, johnlasseter, johnlasseter, joh...
# 1  [joejohnston, joejohnston, joejohnston, joejoh...
#
#                                             keywords  \
# 0  [jealousy toy boy friendship friend rivalry bo...
# 1  [boardgame disappearance basedonchildren'sbook...
#
#                                          description  \
# 0  Led by Woody, Andy's toys live happily in his ...
# 1  When siblings Judy and Peter discover an encha...
#
#                                                  col
# 0  tomhanks timallen donrickles johnlasseter john...
# 1  robinwilliams jonathanhyde kirstendunst joejoh...
#
# [2 rows x 31 columns]

# %%
#using count vectorizer here for keywords because no stop words and every word has equal weights and will not be biased wby stop words
cf=CountVectorizer(analyzer='word',ngram_range=(1,2),min_df=0,stop_words='english')
cf_matrix=cf.fit_transform(sd['col'])

# %%
tf = TfidfVectorizer(analyzer='word',ngram_range=(1, 2),min_df=0, stop_words='english')
tfidf_matrix = tf.fit_transform(sd['description'])
tfidf_matrix.shape
# Out:
# (9219, 268123)

# %%
#check cosine similarity for col
cosine_sim = cosine_similarity(cf_matrix, cf_matrix)

# %%
#checking cosine similarity for description
#cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)
#t=[]

# %%
def get_recommendation(title):
    index=sd[sd['title']==title].index[0]
    scores=list(enumerate(cosine_sim[index]))
    #scores=cosine_sim[index]
    scores=sorted(scores,key=lambda x:x[1],reverse=True)
    scores=scores[1:31]
    t=scores[1:31]
    mov_id=[i[0] for i in scores]
    return sd.iloc[mov_id,8]
get_recommendation('The Dark Knight')
# Out:
# 8031                   The Dark Knight Rises
# 6218                           Batman Begins
# 6623                            The Prestige
# 7648                               Inception
# 2085                               Following
# 4145                                Insomnia
# 3381                                 Memento
# 8613                            Interstellar
# 7659              Batman: Under the Red Hood
# 1134                          Batman Returns
# 2131                                Superman
# 8478    Justice League: Crisis on Two Earths
# 9024      Batman v Superman: Dawn of Justice
# 8001                        Batman: Year One
# 2132                             Superman II
# 6521                        Superman Returns
# 8467                              Kick-Ass 2
# 524                                   Batman
# 8419                            Man of Steel
# 1260                          Batman & Robin
# 2133                            Superman III
# 8872              Captain America: Civil War
# 6733                                    TMNT
# 7583                                Kick-Ass
# 8725            Teenage Mutant Ninja Turtles
# 132                           Batman Forever
# 7811                       All Star Superman
# 8592                            Wonder Woman
# 3049                                   X-Men
# 4635                                      X2
# Name: original_title, dtype: object

# %%
#importing ratings data
ratings=pd.read_csv('data/dataset/ratings_small.csv')

# %%
reader = Reader(rating_scale=(0,5))
da= Dataset.load_from_df(ratings[['userId','movieId','rating']],reader)
#da.split(n_folds=5)

# %%
#trainset=da.build_full_trainset()
#Benchmarkinf the algorithms to see the best one
bm=[]
#iterating over all algorithms
for algorithm in [SVD(), SVDpp(), SlopeOne(), NMF(), NormalPredictor(), KNNBaseline(), KNNBasic(), KNNWithMeans(), KNNWithZScore(), BaselineOnly(), CoClustering()]:
    #performing cross validatio
    results =cross_validate(algorithm,da,measures=['RMSE','MAE'],cv=3,verbose=False)
    #Get results & append algorithm name
    tmp = pd.DataFrame.from_dict(results).mean(axis=0)
    tmp = tmp.append(pd.Series([str(algorithm).split(' ')[0].split('.')[-1]], index=['algorithm']))
    bm.append(tmp)
pd.DataFrame(bm).set_index('algorithm').sort_values('test_rmse')
# Out:
# Estimating biases using als...
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
#                  test_rmse  test_mae    fit_time  test_time
# algorithm
# SVDpp             0.893409  0.685823  226.751324   9.959825
# BaselineOnly      0.896598  0.693453    0.195702   0.133701
# SVD               0.902727  0.695724    3.295737   0.603672
# KNNBaseline       0.905773  0.693399    0.321073   2.670678
# KNNWithMeans      0.926811  0.709506    0.171368   2.292376
# KNNWithZScore     0.929816  0.707449    0.218723   2.596689
# SlopeOne          0.945905  0.723115    3.145252   8.680123
# NMF               0.959642  0.737292    4.352318   0.793733
# CoClustering      0.975928  0.755673    2.576384   0.256796
# KNNBasic          0.978664  0.753128    0.142699   2.010456
# NormalPredictor   1.443267  1.151442    0.108023   0.268746

# %%
svd=SVD()
trainset=da.build_full_trainset()
svd.fit(trainset)

# %%
# final recommendation
#def final_model(userid,title):
ids=pd.read_csv('data/dataset/links_small.csv')[['movieId','tmdbId']]
#map tmdb id to id for ratings
ids.columns=['movieId','id']
def convert_int(x):
    try:
        return int(x)
    except:
        return np.nan
ids['id']=ids['id'].apply(convert_int)
ids=ids.merge(sd[['title','id']], on='id').set_index('title')
indices_map = ids.set_index('id')

# %%
indices=pd.Series(sd.index, index=sd['title'])
title=sd['title']

# %%
def final_recommendor(userid,title):
    index=indices[title]
    tmdbid=ids.loc[title]['id']
    movie_id=ids.loc[title]['movieId']
    sim_scores=list(enumerate(cosine_sim[int(index)]))
    sim_scores=sorted(sim_scores,key=lambda x:x[1],reverse=True)
    sim_scores=sim_scores[1:26]
    movie_indices=[i[0] for i in sim_scores]
    movies=sd.iloc[movie_indices][['title','vote_count','vote_average','year','id']]
    movies['est']=movies['id'].apply(lambda x: svd.predict(userid, indices_map.loc[x]['movieId']).est)
    movies = movies.sort_values('est', ascending=False)
    return movies.head(30)
final_recommendor(1, 'The Terminator')
#get_recommendation('The Dark knight')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-72-b3db099f4def> in <module>
#      12     return movies.head(30)
#      13 final_recommendor(1, 'The Terminator')
# ---> 14 get_recommendation('The Dark knight')
#
# <ipython-input-62-68497da83181> in get_recommendation(title)
#       1 def get_recommendation(title):
# ----> 2     index=sd[sd['title']==title].index[0]
#       3     scores=list(enumerate(cosine_sim[index]))
#       4     #scores=cosine_sim[index]
#       5     scores=sorted(scores,key=lambda x:x[1],reverse=True)
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in __getitem__(self, key)
#    3928         if is_scalar(key):
#    3929             key = com.cast_scalar_indexer(key)
# -> 3930             return getitem(key)
#    3931
#    3932         if isinstance(key, slice):
#
# IndexError: index 0 is out of bounds for axis 0 with size 0
